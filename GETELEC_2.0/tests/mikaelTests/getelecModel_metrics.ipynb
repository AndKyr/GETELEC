# %% [markdown]
# The goal is to make sure code runs as intended and measure performance improvements in relation to old code

# %% [markdown]
# PART 1: TESTING

# %%
import os
import sys

cwd = os.getcwd()

cwd = os.path.abspath(os.path.join(cwd, "..", "..")) + "/src"

print(cwd)
sys.path.append(cwd)
# Out:
# /home/mikael/GETELEC/src

# %%
from getelec import GETELECModel as GTM

# %%
gtm = GTM()

# %% [markdown]
# Now let's see what properties the model has before we do anything

# %%
gtm.getParameters()
# Out:
# {'bandGap': 3.0,
#  'conductionBandBottom': -15.0,
#  'effectiveMassConduction': 1.0,
#  'effectiveMassValence': 1.0,
#  'emitter': <getelec.MetalEmitter at 0x7f3186b7ff70>,
#  'emitterType': 'metal',
#  'field': 5.0,
#  'gamma': 10.0,
#  'numberOfSpectrumPoints': 64,
#  'radius': 1000.0,
#  'temperature': 300.0,
#  'workFunction': 4.5}

# %% [markdown]
# Let's create some dummy data

# %%
import numpy as np

field = np.array([1, 2, 3, 4, 5])
radius = np.full(5, 50)
gamma = np.full(5, 10)
workFunction = np.full(5, 4)
temperature = np.full(5, 300)

conductionBandBottom = 4.05
fermiLevel = 4.61
bandGap = 1.12
effectiveMassConduction = 0.7
effectiveMassValence = 0.5

numberOfSpectrumPoints = 8

# %% [markdown]
# TEST 1: calling properties that were not yet calculated

# %%
print(gtm.getCurrentDensity())
print(gtm.getElectronSpectrum())
print(gtm.getNottinghamHeat())
# Out:
# WARNING, you have asked currentDensity without calculating it first. You might want to run getelecModel.run(calculateCurrentDensity=True) first
# None
# WARNING, you have asked Electron Spectrum without calculating it first. You might want to run getelecModel.run(calculateElectronSpectrum=True) first
# None
# WARNING, you have asked Nottingham heat without calculating it first. You might want to run getelecModel.run(calculateNottinghamHeat=True) first
# None

# %%
gtm.getParameters()
# Out:
# {'bandGap': 3.0,
#  'conductionBandBottom': -15.0,
#  'effectiveMassConduction': 1.0,
#  'effectiveMassValence': 1.0,
#  'emitter': <getelec.MetalEmitter at 0x7f3186b7ff70>,
#  'emitterType': 'metal',
#  'field': 5.0,
#  'gamma': 10.0,
#  'numberOfSpectrumPoints': 64,
#  'radius': 1000.0,
#  'temperature': 300.0,
#  'workFunction': 4.5}

# %% [markdown]
# TEST 2: assigning property in model instantiation (METALS)

# %%
gtm = GTM(emitterType = 'metal', field = field, radius = radius, gamma = gamma, workFunction = workFunction, temperature = temperature, numberOfSpectrumPoints = numberOfSpectrumPoints)

# %%
gtm.getParameters()
# Out:
# {'bandGap': 3.0,
#  'conductionBandBottom': -15.0,
#  'effectiveMassConduction': 1.0,
#  'effectiveMassValence': 1.0,
#  'emitter': <getelec.MetalEmitter at 0x7f3186b8fac0>,
#  'emitterType': 'metal',
#  'field': array([1, 2, 3, 4, 5]),
#  'gamma': array([10, 10, 10, 10, 10]),
#  'numberOfSpectrumPoints': 8,
#  'radius': array([50, 50, 50, 50, 50]),
#  'temperature': array([300, 300, 300, 300, 300]),
#  'workFunction': array([4, 4, 4, 4, 4])}

# %% [markdown]
# TEST 3: running all calculations

# %%
gtm.run(calculateCurrent=True, calculateNottinghamHeat=True, calculateSpectrum=True)

print(f'Current Density: ${gtm.getCurrentDensity()},\nNottingham Heat: ${gtm.getNottinghamHeat()},\nElectronSpectrum: ${gtm.getElectronSpectrum()}')
# Out:
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# Exception ignored in: <function Socket.__del__ at 0x7f32f37e91f0>
# Traceback (most recent call last):
#   File "/home/mikael/.local/lib/python3.8/site-packages/zmq/sugar/socket.py", line 115, in __del__
#     warn(
# ResourceWarning: Unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f3186ba30a0>
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# Current Density: $[3.065928999846314e-27, 1.2855404243286448e-15, 1.6427941472993612e-11, 2.0335586310746925e-09, 3.85960740254955e-08],
# Nottingham Heat: $[2.3584480375558615e-28, 8.501383279341848e-17, 1.9254679186885177e-12, 3.301448269893378e-10, 7.896623671758638e-09],
# ElectronSpectrum: ${'energy': [array([-0.26396502, -0.14501882, -0.02607262,  0.09287358,  0.21181978,
#         0.33076598,  0.44971218]), array([-0.60591261, -0.45743886, -0.30896511, -0.16049136, -0.01201761,
#         0.13645615,  0.2849299 ]), array([-0.92417189, -0.7278714 , -0.53157091, -0.33527043, -0.13896994,
#         0.05733055,  0.25363104]), array([-1.23353316, -0.98787222, -0.74221128, -0.49655035, -0.25088941,
#        -0.00522847,  0.24043247]), array([-1.53574733, -1.24092977, -0.94611221, -0.65129465, -0.35647709,
#        -0.06165952,  0.23315804])], 'electronCount': [array([5.42131090e-29, 7.60980439e-28, 6.73110577e-27, 2.90505145e-27,
#        3.66151764e-28, 4.18048414e-29, 4.57612534e-30]), array([1.27990468e-17, 8.13639321e-17, 4.38531696e-16, 2.24877067e-15,
#        6.41995865e-15, 3.13037295e-16, 5.49859383e-18]), array([8.42825748e-14, 4.76579186e-13, 2.24487750e-12, 9.99474540e-12,
#        4.19736226e-11, 1.69655248e-11, 6.44023215e-14]), array([6.69400786e-12, 3.57380568e-11, 1.58307210e-10, 6.68401636e-10,
#        2.72171334e-09, 5.89258585e-09, 3.63479463e-12]), array([8.69740774e-11, 4.66366330e-10, 2.06675831e-09, 8.57840880e-09,
#        3.41198016e-08, 1.19512191e-07, 6.00139895e-11])]}

# %%
gtm.getParameters()
# Out:
# {'bandGap': 3.0,
#  'conductionBandBottom': -15.0,
#  'effectiveMassConduction': 1.0,
#  'effectiveMassValence': 1.0,
#  'emitter': <getelec.MetalEmitter at 0x7f3186b8fac0>,
#  'emitterType': 'metal',
#  'field': array([1, 2, 3, 4, 5]),
#  'gamma': array([10, 10, 10, 10, 10]),
#  'numberOfSpectrumPoints': 8,
#  'radius': array([50, 50, 50, 50, 50]),
#  'temperature': array([300, 300, 300, 300, 300]),
#  'workFunction': array([4, 4, 4, 4, 4])}

# %% [markdown]
# TEST 4: see what happens when data changes

# %%
print(gtm.field)
gtm.setParameters(field = np.array([2, 3, 4, 5, 6]))
print(gtm.field)
# Out:
# [1 2 3 4 5]
# [2 3 4 5 6]

# %%
gtm.getCurrentDensity()
# Out:
# WARNING, you have asked currentDensity without calculating it first. You might want to run getelecModel.run(calculateCurrentDensity=True) first

# %%
gtm.calculateCurrentDensity()
print(gtm.getCurrentDensity())
# Out:
# Exception ignored in: <function Socket.__del__ at 0x7f32f37e91f0>
# Traceback (most recent call last):
#   File "/home/mikael/.local/lib/python3.8/site-packages/zmq/sugar/socket.py", line 115, in __del__
#     warn(
# ResourceWarning: Unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f3186259ca0>
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# [1.2855404243286448e-15, 1.6427941472993612e-11, 2.0335586310746925e-09, 3.85960740254955e-08, 2.83067849980083e-07]

# %% [markdown]
# TEST 5: big data

# %%
field = np.linspace(1, 10, 1000)
radius = np.full(1000, 50)
gamma = np.full(1000, 10)
workFunction = np.full(1000, 4)
temperature = np.full(1000, 300)

conductionBandBottom = 4.05
fermiLevel = 4.61
bandGap = 1.12
effectiveMassConduction = 0.7
effectiveMassValence = 0.5

numberOfSpectrumPoints = 8

# %%
gtm = GTM(emitterType = 'metal', field = field, radius = radius, gamma = gamma, workFunction = workFunction, temperature = temperature, numberOfSpectrumPoints = numberOfSpectrumPoints)

# %%
gtm.run(calculateCurrent=True, calculateNottinghamHeat=True, calculateSpectrum=True)

print(f'Current Density: ${gtm.getCurrentDensity()},\nNottingham Heat: ${gtm.getNottinghamHeat()},\nElectronSpectrum: ${gtm.getElectronSpectrum()}')
# Out:
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# ...
#        2.86549416e-06, 1.00265015e-05, 5.72809415e-09]), array([7.61632930e-09, 4.12990894e-08, 1.83304654e-07, 7.51559213e-07,
#        2.88191927e-06, 1.00810962e-05, 5.75873824e-09]), array([7.65958288e-09, 4.15362124e-08, 1.84365771e-07, 7.55917026e-07,
#        2.89840553e-06, 1.01358680e-05, 5.78946066e-09]), array([7.70299540e-09, 4.17742279e-08, 1.85430956e-07, 7.60291595e-07,
#        2.91495303e-06, 1.01908169e-05, 5.82026185e-09]), array([7.74652056e-09, 4.20128957e-08, 1.86499189e-07, 7.64678937e-07,
#        2.93154725e-06, 1.02458960e-05, 5.85112032e-09]), array([7.79019713e-09, 4.22524172e-08, 1.87571327e-07, 7.69082400e-07,
#        2.94820036e-06, 1.03011444e-05, 5.87567440e-09]), array([7.83403698e-09, 4.24927553e-08, 1.88647466e-07, 7.73502574e-07,
#        2.96491469e-06, 1.03565630e-05, 5.91311132e-09]), array([7.87803167e-09, 4.27340641e-08, 1.89727754e-07, 7.77939624e-07,
#        2.98169043e-06, 1.04121710e-05, 5.93770188e-09]), array([7.92218569e-09, 4.29762683e-08, 1.90812127e-07, 7.82393502e-07,
#        2.99852758e-06, 1.04679494e-05, 5.97443001e-09]), array([7.96649920e-09, 4.32193693e-08, 1.91900589e-07, 7.86864232e-07,
#        3.01542621e-06, 1.05239045e-05, 6.00564096e-09]), array([8.01097240e-09, 4.34633680e-08, 1.92993146e-07, 7.91351837e-07,
#        3.03238638e-06, 1.05800362e-05, 6.03570713e-09]), array([8.05560545e-09, 4.37082657e-08, 1.94089804e-07, 7.95856341e-07,
#        3.04940816e-06, 1.06363445e-05, 6.06975263e-09]), array([8.10036417e-09, 4.39538850e-08, 1.95189812e-07, 8.00374805e-07,
#        3.06648086e-06, 1.06927951e-05, 6.10125537e-09]), array([8.14526057e-09, 4.42002885e-08, 1.96293436e-07, 8.04908273e-07,
#        3.08360826e-06, 1.07493998e-05, 6.13283099e-09]), array([8.19031681e-09, 4.44475914e-08, 1.97401165e-07, 8.09458663e-07,
#        3.10079730e-06, 1.08061807e-05, 6.16448965e-09]), array([8.23553306e-09, 4.46957949e-08, 1.98513006e-07, 8.14025995e-07,
#        5.36977447e-06, 1.80773157e-05, 1.01107001e-08])]}

# %% [markdown]
# TEST 6: instantiating SEMICONDUCTOR

# %%
gtm = GTM()

gtm.setParameters(emitterType='semiconductor', field = field, radius = radius, gamma = gamma, conductionBandBottom = conductionBandBottom, fermiLevel = fermiLevel, bandGap = bandGap, effectiveMassConduction = effectiveMassConduction, effectiveMassValence = effectiveMassValence, numberOfSpectrumPoints = 8, temperature = temperature, workFunction = workFunction)
# Out:
# <getelec.SemiconductorEmitter object at 0x7f318624edc0>

# %%
gtm.getParameters()
print(gtm.emitter)
# Out:
# <getelec.SemiconductorEmitter object at 0x7f318624edc0>

# %%
gtm.run(True, True, True)

print(f'Current Density: ${gtm.getCurrentDensity()},\nNottingham Heat: ${gtm.getNottinghamHeat()},\nElectronSpectrum: ${gtm.getElectronSpectrum()}')
# Out:
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mikael/GETELEC/src/getelec.py", line 1580, in __run_semiconductor_worker
#     emitter.setParameters(self._getArgument(field, idx), self._getArgument(radius, idx), self._getArgument(gamma, idx), conductionBandBottom, workFunction, bandGap, self._getArgument(kT, idx), effectiveMassConduction, effectiveMassValence)
#   File "/home/mikael/GETELEC/src/getelec.py", line 1291, in setParameters
#     self.conductionEmitter.setParameters(workfunction=workFunction, kT=kT, effectiveMass=effectiveMassConduction, energyBandLimit=conductionBandBottom)
#   File "/home/mikael/GETELEC/src/getelec.py", line 789, in setParameters
#     self._calculateIntegrationLimits()
#   File "/home/mikael/GETELEC/src/getelec.py", line 1022, in _calculateIntegrationLimits
#     maxBetaEnergy = min([self.workFunction, self.barrier.maxEnergyDepth, self.workFunction - self.energyBandLimit])
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Exception ignored in: <function Socket.__del__ at 0x7f32f37e91f0>
# Traceback (most recent call last):
#   File "/home/mikael/.local/lib/python3.8/site-packages/zmq/sugar/socket.py", line 115, in __del__
#     warn(
# ResourceWarning: Unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f318625b100>
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# WARNING: Using tabulation without radius (planar approximation) with input radius: 50 nm < 100 nm.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/mikael/GETELEC/tests/mikaelTests/getelecModel_metrics.ipynb Cell 30 in 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bspinor.matter.ut.ee/home/mikael/GETELEC/tests/mikaelTests/getelecModel_metrics.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> gtm.run(True, True, True)
#       <a href='vscode-notebook-cell://ssh-remote%2Bspinor.matter.ut.ee/home/mikael/GETELEC/tests/mikaelTests/getelecModel_metrics.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> print(f'Current Density: ${gtm.getCurrentDensity()},\nNottingham Heat: ${gtm.getNottinghamHeat()},\nElectronSpectrum: ${gtm.getElectronSpectrum()}')
#
# File ~/GETELEC/src/getelec.py:1669, in GETELECModel.run(self, calculateCurrent, calculateNottinghamHeat, calculateSpectrum, nThreads)
#    1666 _electronSpectrum = {'energy': [], 'electronCount': []}
#    1668 for result in results:
# -> 1669     if(calculateCurrent): _currentDensity.append(result['currentDensity'])
#    1670     if(calculateNottinghamHeat): _nottinghamHeat.append(result['nottinghamHeat'])
#    1671     if(calculateSpectrum):
#
# TypeError: 'NoneType' object is not subscriptable

# %%
new_gtm = GTM('metal', field=field, radius=radius, gamma=gamma, workFunction=workFunction, temperature=temperature)

# %%
new_gtm.calculateCurrentDensity().currentDensity
# Out:
# array([2.15675678e-27, 4.99385567e-16, 1.06113266e-11, 1.57722206e-09,
#        3.26236555e-08])
